# %%
# import mysql.connector
# import pprint
# db={'host':'127.0.0.1',
#     'user':'HUJIAN',
#     'password':'ASDQWE',
#     'database':'vsearchlogDB'}
# conn=mysql.connector.connect(**db)
# cursor=conn.cursor()
# _sql='''insert into log
#         (phrase,letters,ip,browser_string,results)
#         values
#         (%s,%s,%s,%s,%s)'''
# cursor.execute(_sql,('hitch-hiker','xyz','127.0.0.1','safari','set()'))
# conn.commit()
# _sql='''select * from log'''
# cursor.execute(_sql)
# cursor.fetchall()
#

# %% [markdown]
# # import DBcm
# # db = {'host': '127.0.0.1',
# #       'user': 'HUJIAN',
# #       'password': 'ASDQWE',
# #       'database': 'vsearchlogDB'}
# # with DBcm.UseDatabase(db) as cursor:
# #     _sql='''show tables'''
# #     cursor.execute(_sql)
# #     data=cursor.fetchall()
# jupyter notebook无法正确识别类方法和类属性，导入方式如上面所示才不会报错

# %%
tuple(str(list(str(list(str(list(str(dir(dict)))))))))
# Out:
# ('[',
#  "'",
#  '[',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '[',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '[',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '_',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '_',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  'c',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  'l',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  'a',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  's',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  '"',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  "'",
#  ' ',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  '"',
#  "'",
#  '"',
#  ',',
#  ' ',
#  "'",
#  ',',
#  "'",
#  ',',
#  ...)

# %%
# Out:
# function
